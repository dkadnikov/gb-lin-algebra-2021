# %% [markdown]
# ### Урок 2. Матрицы и матричные операции
# ### Часть 1:

# %%
import numpy as np

# %% [markdown]
# #### 1. Установить, какие произведения матриц 𝐴𝐵 и 𝐵𝐴 определены, и найти размерности полученных матриц:<br>
# #### Решение: <br>
# а) 𝐴 — матрица 4×2 , 𝐵 — матрица 4×2 ; - Произведения не определены<br>
# б) 𝐴 — матрица 2×5 , 𝐵 — матрица 5×3 ; - AB - произведение определено, размерность матрицы 2х3 BA - произведение не определено<br>
# в) 𝐴 — матрица 8×3 , 𝐵 — матрица 3×8 ; - AB - размерность 8х8 BA - размерность 3x3<br>
# г) 𝐴 — квадратная матрица 4×4 , 𝐵 — квадратная матрица 4×4; - Размерность матрицы 4х4<br>

# %% [markdown]
# #### 2. Найти сумму и произведение матриц
# $A=\begin{pmatrix}
# 1 &amp; -2\\
# 3 &amp; 0
# \end{pmatrix}$ и $B=\begin{pmatrix}
# 4 &amp; -1\\
# 0 &amp; 5
# \end{pmatrix}.$<br>
#
# #### Решение:
#
#
# $ A + B =
# \begin{pmatrix}
# 1+4 &amp; -2-1\\
# 3+0 &amp; 0+5
# \end{pmatrix} =
# \begin{pmatrix}
# 5 &amp; -3\\
# 3 &amp; 5
# \end{pmatrix}
# $<br>
# $ A * B =
# \begin{pmatrix}
# 4 &amp; -11\\
# 12 &amp; 3
# \end{pmatrix}$

# %% [markdown]
# #### 3. Из закономерностей сложения и умножения матриц на число можно сделать вывод, что матрицы одного размера образуют линейное пространство.
# Вычислить линейную комбинацию $3A-2B+4C$ для матриц $A=\begin{pmatrix}
# 1 &amp; 7\\
# 3 &amp; -6
# \end{pmatrix}$, $B=\begin{pmatrix}
# 0 &amp; 5\\
# 2 &amp; -1
# \end{pmatrix}$, $C=\begin{pmatrix}
# 2 &amp; -4\\
# 1 &amp; 1
# \end{pmatrix}.$<br>
# #### Решение:
# $ X = 3A - 2B = 3*\begin{pmatrix}
# 1 &amp; 7\\
# 3 &amp; -6
# \end{pmatrix} - 2*\begin{pmatrix}
# 0 &amp; 5\\
# 2 &amp; -1
# \end{pmatrix} = \begin{pmatrix}
# 3 &amp; 11\\
# 5 &amp; -16
# \end{pmatrix}$<br>
# $ X + 4C = \begin{pmatrix}
# 3 &amp; 11\\
# 5 &amp; -16
# \end{pmatrix} + 4*\begin{pmatrix}
# 2 &amp; -4\\
# 1 &amp; 1
# \end{pmatrix} = \begin{pmatrix}
# 11 &amp; -5\\
# 9 &amp; -12
# \end{pmatrix} $

# %% [markdown]
# #### 4. Дана матрица $A=\begin{pmatrix}
# 4 & 1\ 5 & -2\ 2 & 3 \end{pmatrix}$.<br>
# #### Вычислить $AA^{T}$ и $A^{T}A$.<br>
# #### Решение:<br>
#
# $ A^T = \begin{pmatrix}
# 4 &amp; 5 &amp; 2\\
# 1 &amp; -2 &amp; 3
# \end{pmatrix} $<br>
# $ A*A^T = \begin{pmatrix}
# 4 &amp; 1\\
# 5 &amp; -2\\
# 2 &amp; 3
# \end{pmatrix} * \begin{pmatrix}
# 4 &amp; 5 &amp; 2\\
# 1 &amp; -2 &amp; 3
# \end{pmatrix} = \begin{pmatrix}
# 17 &amp; 18 &amp; 11\\
# 18 &amp; 29 &amp; 4\\
# 11 &amp; 4 &amp; 13
# \end{pmatrix} $

# %% [markdown]
# ### Часть 2:

# %% [markdown]
# 1. Вычислить определитель
# a)
# $\begin{vmatrix}
# sinx &amp; -cosx\\
# cosx &amp; sinx
# \end{vmatrix} = sinx*sinx-cosx*(-cosx)=sin^2x+cos^2x=1 $
# б)
# $\begin{vmatrix}
# 4 &amp; 2 &amp; 3\\
# 0 &amp; 5 &amp; 1\\
# 0 &amp; 0 &amp; 9
# \end{vmatrix} = 4*5*9 = 180$
# в) Решим методом треугольников
# $\begin{vmatrix}
# 1 &amp; 2 &amp; 3\\
# 4 &amp; 5 &amp; 6\\
# 7 &amp; 8 &amp; 9
# \end{vmatrix} = 45+84+96-105-48-72=0$
# 2 Определитель матрицы A равен 4. Найти:
# a) $ det(A^2) $
# $ det(A^2) = det(A)*det(A) = 16 $
# б) $ det(A^T) $
# $ det(A^T) = 4 $
# в) $ det(2A) = $ Неясна исходная матрица и ее размерность, непонятно как найти определитель
# 3. Доказать, что матрица вырожденная
# $\begin{pmatrix}
# -2 &amp; 7 &amp; -3\\
# 4 &amp; -14 &amp; 6\\
# -3 &amp; 7 &amp; 13
# \end{pmatrix} = 364-126-84+126+84-364 = 0 $ - матрица вырожденная
# 4. Найти ранг матрицы:
# а) $\begin{pmatrix}
# 1 &amp; 2 &amp; 3\\
# 1 &amp; 1 &amp; 1\\
# 2 &amp; 3 &amp; 4
# \end{pmatrix}$
# Умножим 1-ую строку на (-1). Добавим 2-ую строку к 1-ой:
# $\begin{pmatrix}
# 0 &amp; -1 &amp; -2\\
# 1 &amp; 1 &amp; 1\\
# 2 &amp; 3 &amp; 4
# \end{pmatrix}$
# Умножим 2-ую строку на (-2). Добавим 3-ую строку к 2-ой:
# $\begin{pmatrix}
# 0 &amp; -1 &amp; -2\\
# 0 &amp; 1 &amp; 2\\
# 2 &amp; 3 &amp; 4
# \end{pmatrix}$
# В матрице B 1-ая и 2-ая строки пропорциональны, следовательно, одну из них, например 1-ю, можно вычеркнуть. Это равносильно вычеркиванию 1-го уравнения системы, так как оно является следствием 2-го.
# $\begin{pmatrix}
# 0 &amp; 1 &amp; 2\\
# 2 &amp; 3 &amp; 4
# \end{pmatrix}$
# rang(A) = 2
# б) $\begin{pmatrix}
# 0 &amp; 0 &amp; 2 &amp; 1\\
# 0 &amp; 0 &amp; 2 &amp; 2\\
# 0 &amp; 0 &amp; 4 &amp; 3\\
# 2 &amp; 3 &amp; 5 &amp; 6
# \end{pmatrix}$
# Умножим 1-ую строку на (-1). Добавим 2-ую строку к 1-ой:
# $\begin{pmatrix}
# 0 &amp; 0 &amp; 0 &amp; 1\\
# 0 &amp; 0 &amp; 2 &amp; 2\\
# 0 &amp; 0 &amp; 4 &amp; 3\\
# 2 &amp; 3 &amp; 5 &amp; 6
# \end{pmatrix}$
# rang(A) = 4

# %% [markdown]
#  Найти сумму и произведение матриц $A=\begin{pmatrix}
# 1 &amp; -2\\
# 3 &amp; 0
# \end{pmatrix}$ и $B=\begin{pmatrix}
# 4 &amp; -1\\
# 0 &amp; 5
# \end{pmatrix}.$
